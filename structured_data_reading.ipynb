# %%
import pandas as pd
import numpy as np

# %% [raw]
# # Create a simple DataFrame
# data = {
#     "Name": ["Alice", "Bob", "Charlie"],
#     "Age": [23, 30, 28],
#     "City": ["London", "Paris", "New York"]
# }
#
# df = pd.DataFrame(data)
#
# # Display the DataFrame
# print(df)

# %%
df
# Out:
#       Name  Age      City
# 0    Alice   23    London
# 1      Bob   30     Paris
# 2  Charlie   28  New York

# %%
a = np.array([10, 20, 30, 40, 50])
b = np.array([11, 23, 35, 47, 59])

# %%
a.shape=(5,1)
b.shape=(5,1)

# %%
c = np.hstack((a,b))

# %%
pd.DataFrame(c,columns =["column A","column B"])
# Out:
#    column A  column B
# 0        10        11
# 1        20        23
# 2        30        35
# 3        40        47
# 4        50        59

# %%
data1 =pd.read_csv("C:\\Users\\user\\Desktop\\DataScience with Python\\notes and materials\\Boston.csv")

# %%
data1
# Out:
#         crim    zn  indus    nox     rm   age     dis  rad  tax  ptratio  \
# 0    0.00632  18.0   2.31  0.538  6.575  65.2  4.0900    1  296     15.3
# 1    0.02731   0.0   7.07  0.469  6.421  78.9  4.9671    2  242     17.8
# 2    0.02729   0.0   7.07  0.469  7.185  61.1  4.9671    2  242     17.8
# 3    0.03237   0.0   2.18  0.458  6.998  45.8  6.0622    3  222     18.7
# 4    0.06905   0.0   2.18  0.458  7.147  54.2  6.0622    3  222     18.7
# ..       ...   ...    ...    ...    ...   ...     ...  ...  ...      ...
# 501  0.06263   0.0  11.93  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527   0.0  11.93  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076   0.0  11.93  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959   0.0  11.93  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741   0.0  11.93  0.573  6.030  80.8  2.5050    1  273     21.0
#
#       black  lstat  medv
# 0    396.90   4.98  24.0
# 1    396.90   9.14  21.6
# ...

# %%
# Read the iris sheet
data2 = pd.read_excel(
    r"C:\Users\user\Desktop\DataScience with Python\notes and materials\Excel Data.xlsx",
    sheet_name="iris"
)

# %%
# Read the marks sheet
data3= pd.read_excel(
    r"C:\Users\user\Desktop\DataScience with Python\notes and materials\Excel Data.xlsx",
    sheet_name="marks"
)

# %%
data2
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data3
# Out:
#    ID  Marks
# 0   1     67
# 1   2     78
# 2   3     76
# 3   4     66
# 4   5     89

# %%
data1.head()
# Out:
#       crim    zn  indus    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
data3.tail()
# Out:
#    ID  Marks
# 0   1     67
# 1   2     78
# 2   3     76
# 3   4     66
# 4   5     89

# %%
data3.tail(2)
# Out:
#    ID  Marks
# 3   4     66
# 4   5     89
